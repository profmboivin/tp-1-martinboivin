# %% [markdown]
# ## Table des matières pour aujourd'hui
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <p>
# <li><a href="#ref1">Boucle For</a></p></li>
# <li><a href="#ref2">Boucle While</a></p></li>
# </p>
# <p>
# Temps estimé: <strong>50 minutes</strong>
# </p>
# </div>
# <hr>

# %% [markdown]
# <a id="ref1"></a>
# <center><h2>Boucles For</h2></center>

# %% [markdown]
# En Python, une boucle **for** permet d'exécuter un bloc de code de manière répétée, en parcourant les éléments d'une séquence (comme une liste, une chaîne de caractères, etc.) ou en itérant un nombre défini de fois. Elle est particulièrement utile lorsqu'on connaît le nombre d'itérations à l'avance.
#
# La boucle **for** est un outil puissant pour répéter un bloc de code en parcourant des séquences d'éléments. Elle est flexible et peut être utilisée dans de nombreuses situations, que ce soit pour travailler avec des listes, des chaînes de caractères, ou pour itérer un nombre connu de fois.

# %%
dates = [1982,1980,1983]
N=len(dates)

for i in range(N):
    print(dates[i])
# Out:
# 1982
# 1980
# 1983

# %%
for i in range(0,8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# #### Exercice : Écrivez ou modifiez une boucle afin d'écrire les nombres compris entre -5 et 5 inclusivement.

# %%
for ....
    ....

# %% [markdown]
# #### Écrivez un programme qui calcule la somme des N premiers nombres entiers.

# %%
for ....
    ....

# %% [markdown]
# #### Créez un programme qui affiche la table de multiplication d'un nombre donné.

# %%
for ....
    ....

# %% [markdown]
# #### Écrivez un programme qui calcule le factoriel d'un nombre entier positif donné.

# %%
for ....
    ....

# %% [markdown]
# #### Écrivez un programme qui convertit un ensemble de températures de Celsius en Fahrenheit et qui affiche le résultat.

# %%
for ....
    ....

# %% [markdown]
# <a id="ref2"></a>
# <center><h2>Boucle While</h2></center>

# %% [markdown]
# En Python, la boucle **while** exécute un bloc d'instructions tant qu'une condition donnée est vraie. C'est une structure itérative qui permet de répéter un code tant qu'une condition spécifique est satisfaite, sans nécessairement connaître le nombre d'itérations à l'avance.

# %% [markdown]
# Voici un exemple:

# %%
compteur = 0

while compteur < 5:
    print("Le compteur est à", compteur)
    compteur = compteur + 1
# Out:
# Le compteur est à 0
# Le compteur est à 1
# Le compteur est à 2
# Le compteur est à 3
# Le compteur est à 4

# %% [markdown]
# #### Exercice : Écrivez une boucle qui affiche les valeurs comprises dans la liste suivante, en ordre croissant [10, 9.5, 10, 8, 7.5, 5, 10, 10].

# %% [markdown]
# <hr>

# %% [markdown]
# #### Écrivez une boucle while pour copier la chaîne « orange » de la liste « squares » vers la liste « new_squares ». Arrêtez et quittez la boucle si la valeur de la liste n'est pas « orange » :

# %%
squares=['orange','orange','purple','blue ','orange']
new_squares=[];

....

# %% [markdown]
# #### On dispose d'une feuille de papier d'épaisseur 0,1 mm. Combien de fois doit-on la plier au minimum pour que l'épaisseur dépasse la hauteur de la tour Eiffel qui est de 324 m. Écrire un programme en Python pour résoudre ce problème utilisant une boucle while.

# %%
....

# %%
user_name = input("entrez votre nom: ")
print(f"Bonjour, {user_name}!")
# Out:
# entrez votre nom:  Martin
# Bonjour, Martin!
